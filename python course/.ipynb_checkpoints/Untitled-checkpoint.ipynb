# %%
import pandas as pd
path = r"C:\Users\Zhaobin\Desktop\Didi\Git\data_output\Segment\SegmentGeneral_3period\7to9_12to15_15to18_2017Nov_SegGeneral.csv"

# %%
df = pd.read_csv(path)

# %%
df = df.drop_duplicates('driver_id')

# %%
df.head()
# Out:
#    Unnamed: 0        order_id        driver_id        phone  product  \
# 0          70  17596884416482  564634022189564  13691351887        3
# 1         103  17596884427167  563560970784768  18210090478        3
# 2         130  17596882606900  565008777290262  15210545001        3
# 3         145  17596884318474  580542236090413  13701039413        3
# 4         166  17596883111356  563808142036997  17710274609        3
#
#    car_level  order_status  order_type  combo_type   fare  \
# 0        600             5           0           0  11.00
# 1        600             5           0           0  11.00
# 2        600             5           0           0  11.00
# 3        600             5           0           0  13.84
# 4        600             5           0           0  21.27
#
#    driver_start_distance  start_dest_distance          strive_time  \
# 0                    204                 3157  2017-11-01 08:57:42
# ...
